# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from pathlib import Path
from collections import namedtuple
from scipy import stats
import math

#Prevents pandas from truncating data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
#hard coding file pathways for first 2 tests (both VAN and TAN) for baseline and optivisor to variables
base1VAN = pd.read_csv('Brendan-Data/Brendan rbaseline1_baseline_2021-04-20_19-19-21_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base1TAN = pd.read_csv('Brendan-Data/Brendan rbaseline1_baseline_2021-04-20_19-19-48_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base2VAN = pd.read_csv('Brendan-Data/Brendan rbaseline2_baseline_2021-04-20_19-20-41_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base2TAN = pd.read_csv('Brendan-Data/Brendan rbaseline2_baseline_2021-04-20_19-21-05_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base3VAN = pd.read_csv('Brendan-Data/Brendan rbaseline3_baseline_2021-04-20_19-21-53_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base3TAN = pd.read_csv('Brendan-Data/Brendan rbaseline3_baseline_2021-04-20_19-26-55_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base4VAN = pd.read_csv('Brendan-Data/Brendan rbaseline4_baseline_2021-04-20_19-27-39_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base4TAN = pd.read_csv('Brendan-Data/Brendan rbaseline4_baseline_2021-04-20_19-28-00_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base5VAN = pd.read_csv('Brendan-Data/Brendan rbaseline5_baseline_2021-04-20_19-28-41_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base5TAN = pd.read_csv('Brendan-Data/Brendan rbaseline5_baseline_2021-04-20_19-29-12_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base6VAN = pd.read_csv('Brendan-Data/Brendan rbaseline6_baseline_2021-04-20_19-29-53_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base6TAN = pd.read_csv('Brendan-Data/Brendan rbaseline6_baseline_2021-04-20_19-30-22_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base7VAN = pd.read_csv('Brendan-Data/Brendan rbaseline7_baseline_2021-04-20_19-31-04_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base7TAN = pd.read_csv('Brendan-Data/Brendan rbaseline7_baseline_2021-04-20_19-31-25_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base8VAN = pd.read_csv('Brendan-Data/Brendan rbaseline8_baseline_2021-04-20_19-32-00_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base8TAN = pd.read_csv('Brendan-Data/Brendan rbaseline8_baseline_2021-04-20_19-32-24_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base9VAN = pd.read_csv('Brendan-Data/Brendan rbaseline9_baseline_2021-04-20_19-33-03_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base9TAN = pd.read_csv('Brendan-Data/Brendan rbaseline9_baseline_2021-04-20_19-33-28_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base10VAN = pd.read_csv('Brendan-Data/Brendan rbaseline10_baseline_2021-04-20_19-34-14_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base10TAN = pd.read_csv('Brendan-Data/Brendan rbaseline10_baseline_2021-04-20_19-34-32_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


opti1VAN = pd.read_csv('Brendan-Data/Brendan optovisor1_baseline_2021-04-20_19-00-23_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti1TAN = pd.read_csv('Brendan-Data/Brendan optovisor1_baseline_2021-04-20_19-01-01_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti2VAN = pd.read_csv('Brendan-Data/Brendan optovisor2_baseline_2021-04-20_19-02-55_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti2TAN = pd.read_csv('Brendan-Data/Brendan optovisor2_baseline_2021-04-20_19-03-32_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti3VAN = pd.read_csv('Brendan-Data/Brendan optovisor3_baseline_2021-04-20_19-04-44_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti3TAN = pd.read_csv('Brendan-Data/Brendan optovisor3_baseline_2021-04-20_19-05-13_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti4VAN = pd.read_csv('Brendan-Data/Brendan optovisor4_baseline_2021-04-20_19-07-37_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti4TAN = pd.read_csv('Brendan-Data/Brendan optovisor4_baseline_2021-04-20_19-08-24_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti5VAN = pd.read_csv('Brendan-Data/Brendan optovisor5_baseline_2021-04-20_19-09-11_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti5TAN = pd.read_csv('Brendan-Data/Brendan optovisor5_baseline_2021-04-20_19-09-41_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti6VAN = pd.read_csv('Brendan-Data/Brendan optovisor6_baseline_2021-04-20_19-10-36_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti6TAN = pd.read_csv('Brendan-Data/Brendan optovisor6_baseline_2021-04-20_19-11-14_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti7VAN = pd.read_csv('Brendan-Data/Brendan optovisor7_baseline_2021-04-20_19-11-55_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti7TAN = pd.read_csv('Brendan-Data/Brendan optovisor7_baseline_2021-04-20_19-12-33_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti8VAN = pd.read_csv('Brendan-Data/Brendan optovisor8_baseline_2021-04-20_19-13-18_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti8TAN = pd.read_csv('Brendan-Data/Brendan optovisor8_baseline_2021-04-20_19-13-41_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti9VAN = pd.read_csv('Brendan-Data/Brendan optovisor9_baseline_2021-04-20_19-14-49_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti9TAN = pd.read_csv('Brendan-Data/Brendan optovisor9_baseline_2021-04-20_19-15-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti10VAN = pd.read_csv('Brendan-Data/Brendan optovisor10_baseline_2021-04-20_19-16-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti10TAN = pd.read_csv('Brendan-Data/Brendan optovisor10_baseline_2021-04-20_19-16-31_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %%
#Defines the participant names, and arrays (?) for the final stats (RMS = root mean square)
names = ["Brendan"]
tests = ["Baseline", "Optivisor", "Overall Stats"]

##### serena edit: put angle offset calculation here so that you can just play with angle offset values instead of pixels
    # basically, you should take the raw data and convert that to angle offsets, and then calculate from there
    
#Finding ocular misalignment
baseHold = [base1VAN, base2VAN, base3VAN, base4VAN, base5VAN, base6VAN, base7VAN, base8VAN, base9VAN, base10VAN] #holds base data
optiHold = [opti1VAN, opti2VAN, opti3VAN, opti4VAN, opti5VAN, opti6VAN, opti7VAN, opti8VAN, opti9VAN, opti10VAN] # holds opti data
vertMis1 = [] #originally supposed to hold means for baseline, but it didn't work out how I expected (explained later)
vertMis2 = [] #originally supposed to hold means for optivisor, but it didn't work out how I expected (explained later)

for i in range(10):
    holderB = 0
    holderO = 0
    frame1 = baseHold[i] # holds baseline trial from baseHold array
    frame2 = optiHold[i] # holds optivisor trial from optiHold array
    for column in frame1[['YEnd']]:
        ang1 = 180/math.pi * np.arctan((frame1[column]/10)/207)
        ang2 = 180/math.pi * np.arctan((frame2[column]/10)/207)
        holderB += ang1
        holderO += ang2
    holderB /= 10
    holderO /= 10
    vertMis1.append(holderB) # idk why, but after this nested loop, both vertMis1 and vertMis2 hold every individual 
                            #test/10 instead of averages
    vertMis2.append(holderO)

vertMisBaseMean = [] #holds baseline misalignment means for each trial
vertMisOptiMean = [] #holds optivisor misalignment means for each trial
vertMisBaseSD = [] #holds baseline misalignment standard deviation for each trial
vertMisOptiSD = [] #holds optivisor misalignment standard deviation for each trial

for l in range (10):
    vertMisBaseMean.append(vertMis1[l].sum()) #summing each dataframe with misalignment in the verMis1 and 2 arrays
    vertMisOptiMean.append(vertMis2[l].sum())
    vertMisBaseSD.append(vertMis1[l].std())
    vertMisOptiSD.append(vertMis2[l].std())

#creating a dictionary of all the values I need for the table so I don't have to print stuff individually

baseStats = {'Vertical Misalignment Means': vertMisBaseMean,
             'Vertical Misalignment SD': vertMisBaseSD,
             'Vertical Misalignment Final Mean': 0,
             'Vertical Misalignment Final SD': 0,
             'AngEnd Means': [base1TAN['AngEnd'].mean(), 
                              base2TAN['AngEnd'].mean(), 
                              base3TAN['AngEnd'].mean(), 
                              base4TAN['AngEnd'].mean(), 
                              base5TAN['AngEnd'].mean(), 
                              base6TAN['AngEnd'].mean(), 
                              base7TAN['AngEnd'].mean(), 
                              base8TAN['AngEnd'].mean(), 
                              base9TAN['AngEnd'].mean(), 
                              base10TAN['AngEnd'].mean()], 
             'AngEnd SD': [base1TAN['AngEnd'].std(), 
                           base2TAN['AngEnd'].std(), 
                           base3TAN['AngEnd'].std(), 
                           base4TAN['AngEnd'].std(), 
                           base5TAN['AngEnd'].std(), 
                           base6TAN['AngEnd'].std(), 
                           base7TAN['AngEnd'].std(), 
                           base8TAN['AngEnd'].std(), 
                           base9TAN['AngEnd'].std(), 
                           base10TAN['AngEnd'].std()],
             'AngEnd Final Mean': 0, 
             'AngEnd Final SD': 0}

optiStats = {'Vertical Misalignment Means': vertMisOptiMean, 
             'Vertical Misalignment SD': vertMisOptiSD,
             'Vertical Misalignment Final Mean': 0,
             'Vertical Misalignment Final SD': 0, 
             'AngEnd Means': [opti1TAN['AngEnd'].mean(), 
                              opti2TAN['AngEnd'].mean(), 
                              opti3TAN['AngEnd'].mean(), 
                              opti4TAN['AngEnd'].mean(), 
                              opti5TAN['AngEnd'].mean(), 
                              opti6TAN['AngEnd'].mean(), 
                              opti7TAN['AngEnd'].mean(), 
                              opti8TAN['AngEnd'].mean(), 
                              opti9TAN['AngEnd'].mean(), 
                              opti10TAN['AngEnd'].mean()],
             'AngEnd SD': [opti1TAN['AngEnd'].std(), 
                           opti2TAN['AngEnd'].std(), 
                           opti3TAN['AngEnd'].std(), 
                           opti4TAN['AngEnd'].std(), 
                           opti5TAN['AngEnd'].std(), 
                           opti6TAN['AngEnd'].std(), 
                           opti7TAN['AngEnd'].std(), 
                           opti8TAN['AngEnd'].std(), 
                           opti9TAN['AngEnd'].std(), 
                           opti10TAN['AngEnd'].std()],
             'AngEnd Final Mean': 0, 
             'AngEnd Final SD': 0}


#Finding mean values for vertical misalignment and AngEnd for both baseline and optivisor
baseStats['Vertical Misalignment Final Mean'] = np.mean(baseStats['Vertical Misalignment Means'])
baseStats['AngEnd Final Mean'] = np.mean(baseStats['AngEnd Means'])

optiStats['Vertical Misalignment Final Mean'] = np.mean(optiStats['Vertical Misalignment Means'])
optiStats['AngEnd Final Mean'] = np.mean(optiStats['AngEnd Means'])

#Finding the final standard deviation based on the means of each trial
baseStats['Vertical Misalignment Final SD'] = np.std(baseStats['Vertical Misalignment Means'])
baseStats['AngEnd Final SD'] = np.std(baseStats['AngEnd Means'])

optiStats['Vertical Misalignment Final SD'] = np.std(optiStats['Vertical Misalignment Means'])
optiStats['AngEnd Final SD'] = np.std(optiStats['AngEnd Means'])

#Creating dictionary of final stats
finalStats = {'Vertical Misalignment Final Means': [baseStats['Vertical Misalignment Final Mean'], 
                                                    optiStats['Vertical Misalignment Final Mean']],
              'Vertical Misalignment Final SD': [baseStats['Vertical Misalignment Final SD'], 
                                optiStats['Vertical Misalignment Final SD']],
              'Vertical Misalignment P-value': 0,
              'AngEnd Final Means': [baseStats['AngEnd Final Mean'], 
                                     optiStats['AngEnd Final Mean']],
              'AngEnd Final SD': [baseStats['AngEnd Final SD'], 
                                  optiStats['AngEnd Final SD']],
              'AngEnd P-value': 0
             }


#defining the dataframes to later print as tables
data1 = pd.DataFrame(data = baseStats)
data2 = pd.DataFrame(data = optiStats)
data3 = pd.DataFrame(data = finalStats)

data1.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
data2.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
data3.index = ["Baseline", "Optivisor"]

# %% [markdown]
# ## Variable Descriptions
# YEnd Means: Mean YEnd value for each trial (using VAN tests)
# <br>AngEnd Means: Mean AngEnd value for each trial (using TAN tests)
# <br>YEnd SD: Standard deviation of YEnd for each trial (using VAN tests)
# <br>AngEnd SD: Standard deviation of AngEnd for each trial (using TAN tests)
# <br>YEnd RMS: Gives the root mean squared of YEnd for all trials (using VAN tests)
# <br>AngEnd RMS: Gives the root mean squared of AngEnd for all trials (using TAN tests)
# <br>YEnd Final SD: Gives the standard deviation of the YEnd means for all trials (using VAN tests)
# <br>AngEnd Final SD: Give the standard deviation of the AngEnd means for all trials (using TAN tests)

# %%
print(names[0])
print(tests[0])
data1

# serena comments:
    # table looks really great! 
    # based on all the papers it seems like they just go with regular mean and SD, so you can get rid of the RMS and stuff (done)
    # what is 0 and 1, try to specify the row nams
    # everything else looks good, add a couple more lines to include the rest of your data so we can look at everything together
    
#Keep YEnd means, yend sd, yend final mean, yend final sd, angend means, angends sd, angend final mean, angend final sd (done)
#extra table: baseline is first row and optivisor is second row; for each column: final means and sd
# Out:
# Brendan
# Baseline
#           Vertical Misalignment Means  Vertical Misalignment SD  \
# Trial 1                     -0.200949                  0.010871
# Trial 2                     -0.200672                  0.008971
# Trial 3                     -0.188771                  0.008148
# Trial 4                     -0.169118                  0.011400
# Trial 5                     -0.107672                  0.006743
# Trial 6                     -0.109609                  0.013792
# Trial 7                     -0.123172                  0.007639
# Trial 8                     -0.263502                  0.012811
# Trial 9                     -0.197351                  0.009660
# Trial 10                    -0.046224                  0.007505
#
#           Vertical Misalignment Final Mean  Vertical Misalignment Final SD  \
# Trial 1                          -0.160704                        0.059936
# Trial 2                          -0.160704                        0.059936
# Trial 3                          -0.160704                        0.059936
# Trial 4                          -0.160704                        0.059936
# Trial 5                          -0.160704                        0.059936
# Trial 6                          -0.160704                        0.059936
# Trial 7                          -0.160704                        0.059936
# Trial 8                          -0.160704                        0.059936
# Trial 9                          -0.160704                        0.059936
# Trial 10                         -0.160704                        0.059936
#
#           AngEnd Means  AngEnd SD  AngEnd Final Mean  AngEnd Final SD
# Trial 1           0.07   0.847283             -0.035         0.110476
# Trial 2           0.09   0.276687             -0.035         0.110476
# Trial 3          -0.18   0.911409             -0.035         0.110476
# Trial 4          -0.15   1.091635             -0.035         0.110476
# Trial 5           0.05   0.494975             -0.035         0.110476
# Trial 6           0.15   0.492725             -0.035         0.110476
# Trial 7          -0.05   0.707500             -0.035         0.110476
# Trial 8          -0.10   0.724185             -0.035         0.110476
# Trial 9          -0.08   0.674619             -0.035         0.110476
# Trial 10         -0.15   0.365908             -0.035         0.110476

# %%
print(names[0])
print(tests[1])
data2
# Out:
# Brendan
# Optivisor
#           Vertical Misalignment Means  Vertical Misalignment SD  \
# Trial 1                     -0.604472                  0.032566
# Trial 2                     -0.521993                  0.046646
# Trial 3                     -0.439809                  0.046121
# Trial 4                     -0.486031                  0.014609
# Trial 5                     -0.231394                  0.019672
# Trial 6                     -0.478282                  0.010781
# Trial 7                     -0.348475                  0.009185
# Trial 8                     -0.219498                  0.043660
# Trial 9                     -0.144761                  0.008741
# Trial 10                    -0.287304                  0.020361
#
#           Vertical Misalignment Final Mean  Vertical Misalignment Final SD  \
# Trial 1                          -0.376202                        0.144102
# Trial 2                          -0.376202                        0.144102
# Trial 3                          -0.376202                        0.144102
# Trial 4                          -0.376202                        0.144102
# Trial 5                          -0.376202                        0.144102
# Trial 6                          -0.376202                        0.144102
# Trial 7                          -0.376202                        0.144102
# Trial 8                          -0.376202                        0.144102
# Trial 9                          -0.376202                        0.144102
# Trial 10                         -0.376202                        0.144102
#
#           AngEnd Means  AngEnd SD  AngEnd Final Mean  AngEnd Final SD
# Trial 1           0.02   0.736056              0.751          0.29426
# Trial 2           0.55   0.519080              0.751          0.29426
# Trial 3           0.82   0.745058              0.751          0.29426
# Trial 4           0.90   0.790218              0.751          0.29426
# Trial 5           0.75   0.481318              0.751          0.29426
# Trial 6           0.98   0.549343              0.751          0.29426
# Trial 7           0.90   0.439697              0.751          0.29426
# Trial 8           1.18   0.755425              0.751          0.29426
# Trial 9           0.68   0.599630              0.751          0.29426
# Trial 10          0.73   0.374314              0.751          0.29426

# %% [markdown]
# ## next step:
# - put the final angle offset values into the table (replace Yend final means)
# - sanity check: look at kara beaton's paper and see if your data looks anything like hers
#     - if not, check the code/data
# - try to put people in a loop, otherwise ignore and just everyone's data for comparison
# - do the stats:
#     - (probably, but ask mallika) do a ttest on your own data (baseline vs. optivisor)
#     - (eventually when you have a loop or something to get everyone else's data) perform anova (i think)

# %%
# you can convert everything to visual angle offset (within each trial and then found mean) within the table or in a separate table, maybe separate table will
# look better in the end but up to you
# formula from paper: 
    # vertical ocular misalignment = 180/pi * arctan(((pm - ps)*d)/pp)
        # where pm-ps is yend, d is the distance between the head and the screen, and pp is the tablet's resolution in px/inch
    # torsional = am
        # where am is just angend

# %%
#Shapiro-Wilk test to check for normal distribution
stats.shapiro(data1['Vertical Misalignment Means']) #baseline
# first value is w (what is this?) and the second value is the p value
# null hypothesis is that the data is normally distributed
# since p>0.05, we can assume it's normally distributed
# Out:
# ShapiroResult(statistic=0.9502134323120117, pvalue=0.6710265278816223)

# %%
stats.shapiro(data2['Vertical Misalignment Means']) #optivisor
# first value is w (what is this?) and the second value is the p value
# null hypothesis is that the data is normally distributed
# since p>0.05, we can assume it's normally distributed
# Out:
# ShapiroResult(statistic=0.9534103870391846, pvalue=0.7089112401008606)

# %%
#t-test for VAN
vertMisT = stats.ttest_rel(data1['Vertical Misalignment Means'], data2['Vertical Misalignment Means'])
data3['Vertical Misalignment P-value'] = vertMisT[1]

# %%
#t-test for TAN
angMisT = stats.ttest_rel(data1['AngEnd Means'], data2['AngEnd Means'])
data3['AngEnd P-value'] = angMisT[1]

# %%
print(names[0])
print(tests[2])
data3
# Out:
# Brendan
# Overall Stats
#            Vertical Misalignment Final Means  Vertical Misalignment Final SD  \
# Baseline                           -0.160704                        0.059936
# Optivisor                          -0.376202                        0.144102
#
#            Vertical Misalignment P-value  AngEnd Final Means  AngEnd Final SD  \
# Baseline                        0.002101              -0.035         0.110476
# Optivisor                       0.002101               0.751         0.294260
#
#            AngEnd P-value
# Baseline         0.000081
# Optivisor        0.000081
