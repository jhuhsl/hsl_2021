# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from pathlib import Path
from collections import namedtuple
from scipy import stats
import math
import seaborn as sns

#Prevents pandas from truncating data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %% [markdown]
# Arjun's Data

# %%
arjunBase1VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 1_baseline_2021-03-13_21-04-01_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase1TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 1_baseline_2021-03-13_21-04-59_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase2VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 2_baseline_2021-03-13_21-06-52_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase2TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 2_baseline_2021-03-13_21-07-42_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase3VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 3_baseline_2021-03-13_21-09-29_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase3TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 3_baseline_2021-03-13_21-10-19_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase4VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 4_baseline_2021-03-13_21-11-53_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase4TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 4_baseline_2021-03-13_21-12-33_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase5VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 5_baseline_2021-03-13_21-13-50_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase5TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 5_baseline_2021-03-13_21-14-52_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase6VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 6_baseline_2021-03-14_22-22-23_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase6TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 6_baseline_2021-03-14_22-23-42_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase7VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 7_baseline_2021-03-14_22-26-20_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase7TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 7_baseline_2021-03-14_22-27-22_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase8VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 8_baseline_2021-03-14_22-29-32_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase8TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 8_baseline_2021-03-14_22-30-45_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase9VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 9_baseline_2021-03-14_22-32-28_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase9TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 9_baseline_2021-03-14_22-33-33_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase10VAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 10_baseline_2021-03-14_22-34-59_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunBase10TAN = pd.read_csv('Arjun-Data/Arjun Y lenses baseline 10_baseline_2021-03-14_22-35-54_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


arjunOpti1VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 1_baseline_2021-03-13_21-35-01_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti1TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 1_baseline_2021-03-13_21-35-54_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti2VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 2_baseline_2021-03-13_21-36-58_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti2TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 2_baseline_2021-03-13_21-37-48_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti3VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 3_baseline_2021-03-13_21-39-34_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti3TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 3_baseline_2021-03-13_21-40-24_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti4VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 4_baseline_2021-03-13_21-42-30_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti4TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 4_baseline_2021-03-13_21-43-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti5VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 5_baseline_2021-03-13_21-45-34_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti5TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 5_baseline_2021-03-13_21-46-49_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti6VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 6_baseline_2021-03-14_22-37-45_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti6TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 6_baseline_2021-03-14_22-38-57_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti7VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 7_baseline_2021-03-14_22-41-43_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti7TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 7_baseline_2021-03-14_22-42-34_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti8VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 8_baseline_2021-03-14_22-44-34_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti8TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 8_baseline_2021-03-14_22-45-32_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti9VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 9_baseline_2021-03-14_22-47-08_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti9TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 9_baseline_2021-03-14_22-48-13_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti10VAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 10_baseline_2021-03-14_22-49-40_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
arjunOpti10TAN = pd.read_csv('Arjun-Data/Arjun Y lenses optivisor 10_baseline_2021-03-14_22-50-59_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %% [markdown]
# Ashley's Data

# %%
ashleyBase1VAN = pd.read_csv('Ashley-Data/ARW-baseline1_baseline_2021-03-29_22-27-20_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase1TAN = pd.read_csv('Ashley-Data/ARW-baseline1_baseline_2021-03-29_22-28-00_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase2VAN = pd.read_csv('Ashley-Data/ARW-baseline2_baseline_2021-03-29_22-29-39_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase2TAN = pd.read_csv('Ashley-Data/ARW-baseline2_baseline_2021-03-29_22-30-22_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase3VAN = pd.read_csv('Ashley-Data/ARW-baseline3_baseline_2021-03-29_22-31-21_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase3TAN = pd.read_csv('Ashley-Data/ARW-baseline3_baseline_2021-03-29_22-31-49_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase4VAN = pd.read_csv('Ashley-Data/ARW-baseline4_baseline_2021-03-29_22-33-44_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase4TAN = pd.read_csv('Ashley-Data/ARW-baseline4_baseline_2021-03-29_22-34-21_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase5VAN = pd.read_csv('Ashley-Data/ARW-baseline5_baseline_2021-03-29_22-35-00_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase5TAN = pd.read_csv('Ashley-Data/ARW-baseline5_baseline_2021-03-29_22-35-25_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase6VAN = pd.read_csv('Ashley-Data/ARW baseline 6 _baseline_2021-04-01_00-53-02_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase6TAN = pd.read_csv('Ashley-Data/ARW baseline 6 _baseline_2021-04-01_00-53-29_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase7VAN = pd.read_csv('Ashley-Data/ARW baseline 7  _baseline_2021-04-01_00-54-39_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase7TAN = pd.read_csv('Ashley-Data/ARW baseline 7  _baseline_2021-04-01_00-55-09_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase8VAN = pd.read_csv('Ashley-Data/ARW baseline 8  _baseline_2021-04-01_00-55-51_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase8TAN = pd.read_csv('Ashley-Data/ARW baseline 8  _baseline_2021-04-01_00-56-28_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase9VAN = pd.read_csv('Ashley-Data/ARW baseline 9  _baseline_2021-04-01_00-57-12_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase9TAN = pd.read_csv('Ashley-Data/ARW baseline 9  _baseline_2021-04-01_00-57-39_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase10VAN = pd.read_csv('Ashley-Data/ARW baseline 10  _baseline_2021-04-01_00-58-29_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyBase10TAN = pd.read_csv('Ashley-Data/ARW baseline 10  _baseline_2021-04-01_00-58-52_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


ashleyOpti1VAN = pd.read_csv('Ashley-Data/ARW optovisor 1_baseline_2021-03-29_22-38-52_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti1TAN = pd.read_csv('Ashley-Data/ARW optovisor 1_baseline_2021-03-29_22-39-30_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti2VAN = pd.read_csv('Ashley-Data/ARW optovisor 2_baseline_2021-03-29_22-41-26_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti2TAN = pd.read_csv('Ashley-Data/ARW optovisor 2_baseline_2021-03-29_22-41-52_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti3VAN = pd.read_csv('Ashley-Data/ARW optovisor 3_baseline_2021-03-29_22-42-57_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti3TAN = pd.read_csv('Ashley-Data/ARW optovisor 3_baseline_2021-03-29_22-43-19_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti4VAN = pd.read_csv('Ashley-Data/ARW optovisor 4_baseline_2021-03-29_22-44-16_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti4TAN = pd.read_csv('Ashley-Data/ARW optovisor 4_baseline_2021-03-29_22-44-36_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti5VAN = pd.read_csv('Ashley-Data/ARW optovisor 5_baseline_2021-03-29_22-45-11_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti5TAN = pd.read_csv('Ashley-Data/ARW optovisor 5_baseline_2021-03-29_22-45-31_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti6VAN = pd.read_csv('Ashley-Data/ARW optovisor 6  _baseline_2021-04-01_01-01-36_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti6TAN = pd.read_csv('Ashley-Data/ARW optovisor 6  _baseline_2021-04-01_01-01-59_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti7VAN = pd.read_csv('Ashley-Data/ARW optovisor 7  _baseline_2021-04-01_01-02-48_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti7TAN = pd.read_csv('Ashley-Data/ARW optovisor 7  _baseline_2021-04-01_01-03-14_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti8VAN = pd.read_csv('Ashley-Data/ARW optovisor 8  _baseline_2021-04-01_01-04-02_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti8TAN = pd.read_csv('Ashley-Data/ARW optovisor 8  _baseline_2021-04-01_01-04-28_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti9VAN = pd.read_csv('Ashley-Data/ARW optovisor 9  _baseline_2021-04-01_01-05-09_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti9TAN = pd.read_csv('Ashley-Data/ARW optovisor 9  _baseline_2021-04-01_01-05-31_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti10VAN = pd.read_csv('Ashley-Data/ARW optovisor 10  _baseline_2021-04-01_01-06-18_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
ashleyOpti10TAN = pd.read_csv('Ashley-Data/ARW optovisor 10  _baseline_2021-04-01_01-06-42_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %% [markdown]
# Brendan's Data

# %%
brendanBase1VAN = pd.read_csv('Brendan-Data/Brendan rbaseline1_baseline_2021-04-20_19-19-21_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase1TAN = pd.read_csv('Brendan-Data/Brendan rbaseline1_baseline_2021-04-20_19-19-48_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase2VAN = pd.read_csv('Brendan-Data/Brendan rbaseline2_baseline_2021-04-20_19-20-41_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase2TAN = pd.read_csv('Brendan-Data/Brendan rbaseline2_baseline_2021-04-20_19-21-05_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase3VAN = pd.read_csv('Brendan-Data/Brendan rbaseline3_baseline_2021-04-20_19-21-53_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase3TAN = pd.read_csv('Brendan-Data/Brendan rbaseline3_baseline_2021-04-20_19-26-55_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase4VAN = pd.read_csv('Brendan-Data/Brendan rbaseline4_baseline_2021-04-20_19-27-39_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase4TAN = pd.read_csv('Brendan-Data/Brendan rbaseline4_baseline_2021-04-20_19-28-00_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase5VAN = pd.read_csv('Brendan-Data/Brendan rbaseline5_baseline_2021-04-20_19-28-41_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase5TAN = pd.read_csv('Brendan-Data/Brendan rbaseline5_baseline_2021-04-20_19-29-12_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase6VAN = pd.read_csv('Brendan-Data/Brendan rbaseline6_baseline_2021-04-20_19-29-53_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase6TAN = pd.read_csv('Brendan-Data/Brendan rbaseline6_baseline_2021-04-20_19-30-22_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase7VAN = pd.read_csv('Brendan-Data/Brendan rbaseline7_baseline_2021-04-20_19-31-04_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase7TAN = pd.read_csv('Brendan-Data/Brendan rbaseline7_baseline_2021-04-20_19-31-25_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase8VAN = pd.read_csv('Brendan-Data/Brendan rbaseline8_baseline_2021-04-20_19-32-00_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase8TAN = pd.read_csv('Brendan-Data/Brendan rbaseline8_baseline_2021-04-20_19-32-24_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase9VAN = pd.read_csv('Brendan-Data/Brendan rbaseline9_baseline_2021-04-20_19-33-03_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase9TAN = pd.read_csv('Brendan-Data/Brendan rbaseline9_baseline_2021-04-20_19-33-28_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase10VAN = pd.read_csv('Brendan-Data/Brendan rbaseline10_baseline_2021-04-20_19-34-14_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanBase10TAN = pd.read_csv('Brendan-Data/Brendan rbaseline10_baseline_2021-04-20_19-34-32_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


brendanOpti1VAN = pd.read_csv('Brendan-Data/Brendan optovisor1_baseline_2021-04-20_19-00-23_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti1TAN = pd.read_csv('Brendan-Data/Brendan optovisor1_baseline_2021-04-20_19-01-01_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti2VAN = pd.read_csv('Brendan-Data/Brendan optovisor2_baseline_2021-04-20_19-02-55_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti2TAN = pd.read_csv('Brendan-Data/Brendan optovisor2_baseline_2021-04-20_19-03-32_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti3VAN = pd.read_csv('Brendan-Data/Brendan optovisor3_baseline_2021-04-20_19-04-44_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti3TAN = pd.read_csv('Brendan-Data/Brendan optovisor3_baseline_2021-04-20_19-05-13_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti4VAN = pd.read_csv('Brendan-Data/Brendan optovisor4_baseline_2021-04-20_19-07-37_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti4TAN = pd.read_csv('Brendan-Data/Brendan optovisor4_baseline_2021-04-20_19-08-24_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti5VAN = pd.read_csv('Brendan-Data/Brendan optovisor5_baseline_2021-04-20_19-09-11_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti5TAN = pd.read_csv('Brendan-Data/Brendan optovisor5_baseline_2021-04-20_19-09-41_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti6VAN = pd.read_csv('Brendan-Data/Brendan optovisor6_baseline_2021-04-20_19-10-36_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti6TAN = pd.read_csv('Brendan-Data/Brendan optovisor6_baseline_2021-04-20_19-11-14_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti7VAN = pd.read_csv('Brendan-Data/Brendan optovisor7_baseline_2021-04-20_19-11-55_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti7TAN = pd.read_csv('Brendan-Data/Brendan optovisor7_baseline_2021-04-20_19-12-33_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti8VAN = pd.read_csv('Brendan-Data/Brendan optovisor8_baseline_2021-04-20_19-13-18_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti8TAN = pd.read_csv('Brendan-Data/Brendan optovisor8_baseline_2021-04-20_19-13-41_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti9VAN = pd.read_csv('Brendan-Data/Brendan optovisor9_baseline_2021-04-20_19-14-49_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti9TAN = pd.read_csv('Brendan-Data/Brendan optovisor9_baseline_2021-04-20_19-15-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti10VAN = pd.read_csv('Brendan-Data/Brendan optovisor10_baseline_2021-04-20_19-16-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
brendanOpti10TAN = pd.read_csv('Brendan-Data/Brendan optovisor10_baseline_2021-04-20_19-16-31_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %% [markdown]
# Serena's Data

# %%
serenaBase1VAN = pd.read_csv('Serena-Data/Serena baseline 1_baseline_2021-03-15_14-31-39_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase1TAN = pd.read_csv('Serena-Data/Serena baseline 1_baseline_2021-03-15_14-32-01_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase2VAN = pd.read_csv('Serena-Data/Serena baseline 2_baseline_2021-03-15_14-35-13_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase2TAN = pd.read_csv('Serena-Data/Serena baseline 2_baseline_2021-03-15_14-35-31_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase3VAN = pd.read_csv('Serena-Data/Serena baseline 3_baseline_2021-03-15_14-36-07_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase3TAN = pd.read_csv('Serena-Data/Serena baseline 3_baseline_2021-03-15_14-36-22_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase4VAN = pd.read_csv('Serena-Data/Serena baseline 4_baseline_2021-03-15_14-37-00_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase4TAN = pd.read_csv('Serena-Data/Serena baseline 4_baseline_2021-03-15_14-37-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase5VAN = pd.read_csv('Serena-Data/Serena baseline 5_baseline_2021-03-15_14-37-49_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase5TAN = pd.read_csv('Serena-Data/Serena baseline 5_baseline_2021-03-15_14-38-09_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase6VAN = pd.read_csv('Serena-Data/Serena baseline 6_baseline_2021-03-16_14-34-19_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase6TAN = pd.read_csv('Serena-Data/Serena baseline 6_baseline_2021-03-16_14-34-39_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase7VAN = pd.read_csv('Serena-Data/Serena baseline 7_baseline_2021-03-16_14-35-16_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase7TAN = pd.read_csv('Serena-Data/Serena baseline 7_baseline_2021-03-16_14-35-36_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase8VAN = pd.read_csv('Serena-Data/Serena baseline 8_baseline_2021-03-16_14-36-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase8TAN = pd.read_csv('Serena-Data/Serena baseline 8_baseline_2021-03-16_14-36-27_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase9VAN = pd.read_csv('Serena-Data/Serena baseline 9_baseline_2021-03-16_14-37-03_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase9TAN = pd.read_csv('Serena-Data/Serena baseline 9_baseline_2021-03-16_14-37-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase10VAN = pd.read_csv('Serena-Data/Serena baseline 10_baseline_2021-03-16_14-37-50_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaBase10TAN = pd.read_csv('Serena-Data/Serena baseline 10_baseline_2021-03-16_14-38-07_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


serenaOpti1VAN = pd.read_csv('Serena-Data/Serena optovisor 1_baseline_2021-03-15_14-40-49_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti1TAN = pd.read_csv('Serena-Data/Serena optovisor 1_baseline_2021-03-15_14-41-15_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti2VAN = pd.read_csv('Serena-Data/Serena optovisor 2_baseline_2021-03-15_14-41-58_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti2TAN = pd.read_csv('Serena-Data/Serena optovisor 2_baseline_2021-03-15_14-42-20_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti3VAN = pd.read_csv('Serena-Data/Serena optovisor 3_baseline_2021-03-15_14-42-56_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti3TAN = pd.read_csv('Serena-Data/Serena optovisor 3_baseline_2021-03-15_14-43-18_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti4VAN = pd.read_csv('Serena-Data/Serena optovisor 4_baseline_2021-03-15_14-44-00_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti4TAN = pd.read_csv('Serena-Data/Serena optovisor 4_baseline_2021-03-15_14-44-20_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti5VAN = pd.read_csv('Serena-Data/Serena optovisor 5_baseline_2021-03-15_14-44-54_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti5TAN = pd.read_csv('Serena-Data/Serena optovisor 5_baseline_2021-03-15_14-45-14_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti6VAN = pd.read_csv('Serena-Data/Serena optovisor 6_baseline_2021-03-16_14-40-26_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti6TAN = pd.read_csv('Serena-Data/Serena optovisor 6_baseline_2021-03-16_14-40-46_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti7VAN = pd.read_csv('Serena-Data/Serena optovisor 7_baseline_2021-03-16_14-41-29_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti7TAN = pd.read_csv('Serena-Data/Serena optovisor 7_baseline_2021-03-16_14-41-44_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti8VAN = pd.read_csv('Serena-Data/Serena optovisor 8_baseline_2021-03-16_14-42-19_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti8TAN = pd.read_csv('Serena-Data/Serena optovisor 8_baseline_2021-03-16_14-42-34_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti9VAN = pd.read_csv('Serena-Data/Serena optovisor 9_baseline_2021-03-16_14-43-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti9TAN = pd.read_csv('Serena-Data/Serena optovisor 9_baseline_2021-03-16_14-43-25_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti10VAN = pd.read_csv('Serena-Data/Serena optovisor 10_baseline_2021-03-16_14-44-02_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
serenaOpti10TAN = pd.read_csv('Serena-Data/Serena optovisor 10_baseline_2021-03-16_14-44-28_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %% [markdown]
# Mallika's Data

# %%
mallikaBase1VAN = pd.read_csv('Mallika-Data/Mallika rbaseline1 _baseline_2021-04-20_19-57-44_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase1TAN = pd.read_csv('Mallika-Data/Mallika rbaseline1 _baseline_2021-04-20_19-58-12_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase2VAN = pd.read_csv('Mallika-Data/Mallika rbaseline2 _baseline_2021-04-20_19-59-26_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase2TAN = pd.read_csv('Mallika-Data/Mallika rbaseline2 _baseline_2021-04-20_19-59-56_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase3VAN = pd.read_csv('Mallika-Data/Mallika rbaseline3 _baseline_2021-04-20_20-00-52_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase3TAN = pd.read_csv('Mallika-Data/Mallika rbaseline3 _baseline_2021-04-20_20-01-16_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase4VAN = pd.read_csv('Mallika-Data/Mallika rbaseline4_baseline_2021-04-20_20-02-24_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase4TAN = pd.read_csv('Mallika-Data/Mallika rbaseline4_baseline_2021-04-20_20-02-52_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase5VAN = pd.read_csv('Mallika-Data/Mallika rbaseline5_baseline_2021-04-20_20-03-35_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase5TAN = pd.read_csv('Mallika-Data/Mallika rbaseline5_baseline_2021-04-20_20-04-02_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase6VAN = pd.read_csv('Mallika-Data/Mallika rbaseline6_baseline_2021-04-20_20-04-46_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase6TAN = pd.read_csv('Mallika-Data/Mallika rbaseline6_baseline_2021-04-20_20-05-15_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase7VAN = pd.read_csv('Mallika-Data/Mallika rbaseline7_baseline_2021-04-20_20-06-01_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase7TAN = pd.read_csv('Mallika-Data/Mallika rbaseline7_baseline_2021-04-20_20-06-31_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase8VAN = pd.read_csv('Mallika-Data/Mallika rbaseline8_baseline_2021-04-20_20-07-11_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase8TAN = pd.read_csv('Mallika-Data/Mallika rbaseline8_baseline_2021-04-20_20-07-34_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase9VAN = pd.read_csv('Mallika-Data/Mallika rbaseline9_baseline_2021-04-20_20-08-31_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase9TAN = pd.read_csv('Mallika-Data/Mallika rbaseline9_baseline_2021-04-20_20-08-58_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase10VAN = pd.read_csv('Mallika-Data/Mallika rbaseline10_baseline_2021-04-20_20-09-40_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaBase10TAN = pd.read_csv('Mallika-Data/Mallika rbaseline10_baseline_2021-04-20_20-10-04_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


mallikaOpti1VAN = pd.read_csv('Mallika-Data/Mallika optivisor1_baseline_2021-04-20_19-34-31_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti1TAN = pd.read_csv('Mallika-Data/Mallika optivisor1_baseline_2021-04-20_19-35-21_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti2VAN = pd.read_csv('Mallika-Data/Mallika optivisor2_baseline_2021-04-20_19-36-58_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti2TAN = pd.read_csv('Mallika-Data/Mallika optivisor2_baseline_2021-04-20_19-37-38_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti3VAN = pd.read_csv('Mallika-Data/Mallika optivisor3_baseline_2021-04-20_19-38-46_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti3TAN = pd.read_csv('Mallika-Data/Mallika optivisor3_baseline_2021-04-20_19-39-19_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti4VAN = pd.read_csv('Mallika-Data/Mallika optivisor4_baseline_2021-04-20_19-40-18_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti4TAN = pd.read_csv('Mallika-Data/Mallika optivisor4_baseline_2021-04-20_19-40-52_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti5VAN = pd.read_csv('Mallika-Data/Mallika optivisor5_baseline_2021-04-20_19-41-44_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti5TAN = pd.read_csv('Mallika-Data/Mallika optivisor5_baseline_2021-04-20_19-42-16_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti6VAN = pd.read_csv('Mallika-Data/Mallika optivisor6_baseline_2021-04-20_19-43-30_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti6TAN = pd.read_csv('Mallika-Data/Mallika optivisor6_baseline_2021-04-20_19-44-23_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti7VAN = pd.read_csv('Mallika-Data/Mallika optivisor7_baseline_2021-04-20_19-48-59_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti7TAN = pd.read_csv('Mallika-Data/Mallika optivisor7_baseline_2021-04-20_19-49-47_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti8VAN = pd.read_csv('Mallika-Data/Mallika optivisor8_baseline_2021-04-20_19-50-58_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti8TAN = pd.read_csv('Mallika-Data/Mallika optivisor8_baseline_2021-04-20_19-51-25_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti9VAN = pd.read_csv('Mallika-Data/Mallika optivisor9_baseline_2021-04-20_19-52-15_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti9TAN = pd.read_csv('Mallika-Data/Mallika optivisor9_baseline_2021-04-20_19-52-38_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti10VAN = pd.read_csv('Mallika-Data/Mallika optovisor10 _baseline_2021-04-20_19-54-19_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
mallikaOpti10TAN = pd.read_csv('Mallika-Data/Mallika optovisor10 _baseline_2021-04-20_19-54-52_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %%
#One function for all the tests
def basicStats(baseVAN, optiVAN, baseTAN, optiTAN):
    vertMis1 = [] #originally supposed to hold means for baseline, but it didn't work out how I expected (explained later)
    vertMis2 = [] #originally supposed to hold means for optivisor, but it didn't work out how I expected (explained later)
   
    #finding ocular misalignment
    for i in range(10):
        holderB = 0
        holderO = 0
        frame1 = baseVAN[i] # holds baseline trial from baseHold array
        frame2 = optiVAN[i] # holds optivisor trial from optiHold array
        for column in frame1[['YEnd']]:
            ang1 = 180/math.pi * np.arctan((frame1[column]/10)/207)
            ang2 = 180/math.pi * np.arctan((frame2[column]/10)/207)
            holderB += ang1
            holderO += ang2
        holderB /= 10
        holderO /= 10
        vertMis1.append(holderB) # idk why, but after this nested loop, both vertMis1 and vertMis2 hold every individual 
                                #test/10 instead of averages
        vertMis2.append(holderO)

    vertMisBaseMean = [] #holds baseline misalignment means for each trial
    vertMisOptiMean = [] #holds optivisor misalignment means for each trial
    vertMisBaseSD = [] #holds baseline misalignment standard deviation for each trial
    vertMisOptiSD = [] #holds optivisor misalignment standard deviation for each trial

    for l in range (10):
        vertMisBaseMean.append(vertMis1[l].sum()) #summing each dataframe with misalignment in the verMis1 and 2 arrays
        vertMisOptiMean.append(vertMis2[l].sum())
        vertMisBaseSD.append(vertMis1[l].std())
        vertMisOptiSD.append(vertMis2[l].std())

    #creating a dictionary of all the values I need for the table so I don't have to print stuff individually

    baseStats = {'Vertical Misalignment Means': vertMisBaseMean,
                 'Vertical Misalignment SD': vertMisBaseSD,
                 'Vertical Misalignment Final Mean': 0,
                 'Vertical Misalignment Final SD': 0,
                 'AngEnd Means': [baseTAN[0]['AngEnd'].mean(), 
                                  baseTAN[1]['AngEnd'].mean(), 
                                  baseTAN[2]['AngEnd'].mean(), 
                                  baseTAN[3]['AngEnd'].mean(), 
                                  baseTAN[4]['AngEnd'].mean(), 
                                  baseTAN[5]['AngEnd'].mean(), 
                                  baseTAN[6]['AngEnd'].mean(), 
                                  baseTAN[7]['AngEnd'].mean(), 
                                  baseTAN[8]['AngEnd'].mean(), 
                                  baseTAN[9]['AngEnd'].mean()], 
                 'AngEnd SD': [baseTAN[0]['AngEnd'].std(), 
                               baseTAN[1]['AngEnd'].std(), 
                               baseTAN[2]['AngEnd'].std(), 
                               baseTAN[3]['AngEnd'].std(), 
                               baseTAN[4]['AngEnd'].std(), 
                               baseTAN[5]['AngEnd'].std(), 
                               baseTAN[6]['AngEnd'].std(), 
                               baseTAN[7]['AngEnd'].std(), 
                               baseTAN[8]['AngEnd'].std(), 
                               baseTAN[9]['AngEnd'].std()],
                 'AngEnd Final Mean': 0, 
                 'AngEnd Final SD': 0}

    optiStats = {'Vertical Misalignment Means': vertMisOptiMean, 
                 'Vertical Misalignment SD': vertMisOptiSD,
                 'Vertical Misalignment Final Mean': 0,
                 'Vertical Misalignment Final SD': 0, 
                 'AngEnd Means': [optiTAN[0]['AngEnd'].mean(), 
                                  optiTAN[1]['AngEnd'].mean(), 
                                  optiTAN[2]['AngEnd'].mean(), 
                                  optiTAN[3]['AngEnd'].mean(), 
                                  optiTAN[4]['AngEnd'].mean(), 
                                  optiTAN[5]['AngEnd'].mean(), 
                                  optiTAN[6]['AngEnd'].mean(), 
                                  optiTAN[7]['AngEnd'].mean(), 
                                  optiTAN[8]['AngEnd'].mean(), 
                                  optiTAN[9]['AngEnd'].mean()],
                 'AngEnd SD': [optiTAN[0]['AngEnd'].std(), 
                               optiTAN[1]['AngEnd'].std(), 
                               optiTAN[2]['AngEnd'].std(), 
                               optiTAN[3]['AngEnd'].std(), 
                               optiTAN[4]['AngEnd'].std(), 
                               optiTAN[5]['AngEnd'].std(), 
                               optiTAN[6]['AngEnd'].std(), 
                               optiTAN[7]['AngEnd'].std(), 
                               optiTAN[8]['AngEnd'].std(), 
                               optiTAN[9]['AngEnd'].std()],
                 'AngEnd Final Mean': 0, 
                 'AngEnd Final SD': 0}


    #Finding mean values for vertical misalignment and AngEnd for both baseline and optivisor
    baseStats['Vertical Misalignment Final Mean'] = np.mean(baseStats['Vertical Misalignment Means'])
    baseStats['AngEnd Final Mean'] = np.mean(baseStats['AngEnd Means'])

    optiStats['Vertical Misalignment Final Mean'] = np.mean(optiStats['Vertical Misalignment Means'])
    optiStats['AngEnd Final Mean'] = np.mean(optiStats['AngEnd Means'])

    #Finding the final standard deviation based on the means of each trial
    baseStats['Vertical Misalignment Final SD'] = np.std(baseStats['Vertical Misalignment Means'])
    baseStats['AngEnd Final SD'] = np.std(baseStats['AngEnd Means'])

    optiStats['Vertical Misalignment Final SD'] = np.std(optiStats['Vertical Misalignment Means'])
    optiStats['AngEnd Final SD'] = np.std(optiStats['AngEnd Means'])

    #Creating dictionary of final stats
    finalStats = {'Vertical Misalignment Final Means': [baseStats['Vertical Misalignment Final Mean'], 
                                                        optiStats['Vertical Misalignment Final Mean']],
                  'Vertical Misalignment Final SD': [baseStats['Vertical Misalignment Final SD'], 
                                    optiStats['Vertical Misalignment Final SD']],
                  'Vertical Misalignment T-test': 0,
                  'Vertical Misalignment F-test': 0,
                  'AngEnd Final Means': [baseStats['AngEnd Final Mean'], 
                                         optiStats['AngEnd Final Mean']],
                  'AngEnd Final SD': [baseStats['AngEnd Final SD'], 
                                      optiStats['AngEnd Final SD']],
                  'AngEnd T-test': 0,
                  'AngEnd F-test':0
                 }


    #defining the dataframes to later print as tables
    data1 = pd.DataFrame(data = baseStats)
    data2 = pd.DataFrame(data = optiStats)
    data3 = pd.DataFrame(data = finalStats)
    
    vertMisT = stats.ttest_rel(data1['Vertical Misalignment Means'], data2['Vertical Misalignment Means'])
    data3['Vertical Misalignment T-test'] = vertMisT[1]
    angMisT = stats.ttest_rel(data1['AngEnd Means'], data2['AngEnd Means'])
    data3['AngEnd T-test'] = angMisT[1]
    
    data1.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
    data2.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
    data3.index = ["Baseline", "Optivisor"]

    x = np.array(data1['Vertical Misalignment Means'])
    y = np.array(data2['Vertical Misalignment Means'])
    f = np.var(x, ddof=1)/np.var(y, ddof=1) #calculate F test statistic 
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1-stats.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    data3['AngEnd F-test'] = f
    return data1, data2, data3

# %%
arjunBaseVANHold = [arjunBase1VAN, arjunBase2VAN, arjunBase3VAN, arjunBase4VAN, arjunBase5VAN, arjunBase6VAN, arjunBase7VAN, arjunBase8VAN, arjunBase9VAN, arjunBase10VAN] #holds base data
arjunOptiVANHold = [arjunOpti1VAN, arjunOpti2VAN, arjunOpti3VAN, arjunOpti4VAN, arjunOpti5VAN, arjunOpti6VAN, arjunOpti7VAN, arjunOpti8VAN, arjunOpti9VAN, arjunOpti10VAN] # holds opti data
arjunBaseTANHold = [arjunBase1TAN, arjunBase2TAN, arjunBase3TAN, arjunBase4TAN, arjunBase5TAN, arjunBase6TAN, arjunBase7TAN, arjunBase8TAN, arjunBase9TAN, arjunBase10TAN]
arjunOptiTANHold = [arjunOpti1TAN, arjunOpti2TAN, arjunOpti3TAN, arjunOpti4TAN, arjunOpti5TAN, arjunOpti6TAN, arjunOpti7TAN, arjunOpti8TAN, arjunOpti9TAN, arjunOpti10TAN]

arjun = basicStats(arjunBaseVANHold, arjunOptiVANHold, arjunBaseTANHold, arjunOptiTANHold)

# %%
ashleyBaseVANHold = [ashleyBase1VAN, ashleyBase2VAN, ashleyBase3VAN, ashleyBase4VAN, ashleyBase5VAN, ashleyBase6VAN, ashleyBase7VAN, ashleyBase8VAN, ashleyBase9VAN, ashleyBase10VAN] #holds base data
ashleyOptiVANHold = [ashleyOpti1VAN, ashleyOpti2VAN, ashleyOpti3VAN, ashleyOpti4VAN, ashleyOpti5VAN, ashleyOpti6VAN, ashleyOpti7VAN, ashleyOpti8VAN, ashleyOpti9VAN, ashleyOpti10VAN] # holds opti data
ashleyBaseTANHold = [ashleyBase1TAN, ashleyBase2TAN, ashleyBase3TAN, ashleyBase4TAN, ashleyBase5TAN, ashleyBase6TAN, ashleyBase7TAN, ashleyBase8TAN, ashleyBase9TAN, ashleyBase10TAN]
ashleyOptiTANHold = [ashleyOpti1TAN, ashleyOpti2TAN, ashleyOpti3TAN, ashleyOpti4TAN, ashleyOpti5TAN, ashleyOpti6TAN, ashleyOpti7TAN, ashleyOpti8TAN, ashleyOpti9TAN, ashleyOpti10TAN]

ashley = basicStats(ashleyBaseVANHold, ashleyOptiVANHold, ashleyBaseTANHold, ashleyOptiTANHold)

# %%
brendanBaseVANHold = [brendanBase1VAN, brendanBase2VAN, brendanBase3VAN, brendanBase4VAN, brendanBase5VAN, brendanBase6VAN, brendanBase7VAN, brendanBase8VAN, brendanBase9VAN, brendanBase10VAN] #holds base data
brendanOptiVANHold = [brendanOpti1VAN, brendanOpti2VAN, brendanOpti3VAN, brendanOpti4VAN, brendanOpti5VAN, brendanOpti6VAN, brendanOpti7VAN, brendanOpti8VAN, brendanOpti9VAN, brendanOpti10VAN] # holds opti data
brendanBaseTANHold = [brendanBase1TAN, brendanBase2TAN, brendanBase3TAN, brendanBase4TAN, brendanBase5TAN, brendanBase6TAN, brendanBase7TAN, brendanBase8TAN, brendanBase9TAN, brendanBase10TAN]
brendanOptiTANHold = [brendanOpti1TAN, brendanOpti2TAN, brendanOpti3TAN, brendanOpti4TAN, brendanOpti5TAN, brendanOpti6TAN, brendanOpti7TAN, brendanOpti8TAN, brendanOpti9TAN, brendanOpti10TAN]

brendan = basicStats(brendanBaseVANHold, brendanOptiVANHold, brendanBaseTANHold, brendanOptiTANHold)

# %%
serenaBaseVANHold = [serenaBase1VAN, serenaBase2VAN, serenaBase3VAN, serenaBase4VAN, serenaBase5VAN, serenaBase6VAN, serenaBase7VAN, serenaBase8VAN, serenaBase9VAN, serenaBase10VAN] #holds base data
serenaOptiVANHold = [serenaOpti1VAN, serenaOpti2VAN, serenaOpti3VAN, serenaOpti4VAN, serenaOpti5VAN, serenaOpti6VAN, serenaOpti7VAN, serenaOpti8VAN, serenaOpti9VAN, serenaOpti10VAN] # holds opti data
serenaBaseTANHold = [serenaBase1TAN, serenaBase2TAN, serenaBase3TAN, serenaBase4TAN, serenaBase5TAN, serenaBase6TAN, serenaBase7TAN, serenaBase8TAN, serenaBase9TAN, serenaBase10TAN]
serenaOptiTANHold = [serenaOpti1TAN, serenaOpti2TAN, serenaOpti3TAN, serenaOpti4TAN, serenaOpti5TAN, serenaOpti6TAN, serenaOpti7TAN, serenaOpti8TAN, serenaOpti9TAN, serenaOpti10TAN]

serena = basicStats(serenaBaseVANHold, serenaOptiVANHold, serenaBaseTANHold, serenaOptiTANHold)

# %%
mallikaBaseVANHold = [mallikaBase1VAN, mallikaBase2VAN, mallikaBase3VAN, mallikaBase4VAN, mallikaBase5VAN, mallikaBase6VAN, mallikaBase7VAN, mallikaBase8VAN, mallikaBase9VAN, mallikaBase10VAN] #holds base data
mallikaOptiVANHold = [mallikaOpti1VAN, mallikaOpti2VAN, mallikaOpti3VAN, mallikaOpti4VAN, mallikaOpti5VAN, mallikaOpti6VAN, mallikaOpti7VAN, mallikaOpti8VAN, mallikaOpti9VAN, mallikaOpti10VAN] # holds opti data
mallikaBaseTANHold = [mallikaBase1TAN, mallikaBase2TAN, mallikaBase3TAN, mallikaBase4TAN, mallikaBase5TAN, mallikaBase6TAN, mallikaBase7TAN, mallikaBase8TAN, mallikaBase9TAN, mallikaBase10TAN]
mallikaOptiTANHold = [mallikaOpti1TAN, mallikaOpti2TAN, mallikaOpti3TAN, mallikaOpti4TAN, mallikaOpti5TAN, mallikaOpti6TAN, mallikaOpti7TAN, mallikaOpti8TAN, mallikaOpti9TAN, mallikaOpti10TAN]

mallika = basicStats(mallikaBaseVANHold, mallikaOptiVANHold, mallikaBaseTANHold, mallikaOptiTANHold)

# %%
bVAN = [arjun[2]['Vertical Misalignment Final Means'][0], ashley[2]['Vertical Misalignment Final Means'][0], brendan[2]['Vertical Misalignment Final Means'][0], serena[2]['Vertical Misalignment Final Means'][0], mallika[2]['Vertical Misalignment Final Means'][0]]
bVANSD = [arjun[2]['Vertical Misalignment Final SD'][0], ashley[2]['Vertical Misalignment Final SD'][0], brendan[2]['Vertical Misalignment Final SD'][0], serena[2]['Vertical Misalignment Final SD'][0], mallika[2]['Vertical Misalignment Final SD'][0]]
oVAN = [arjun[2]['Vertical Misalignment Final Means'][1], ashley[2]['Vertical Misalignment Final Means'][1], brendan[2]['Vertical Misalignment Final Means'][1], serena[2]['Vertical Misalignment Final Means'][1], mallika[2]['Vertical Misalignment Final Means'][1]]
oVANSD = [arjun[2]['Vertical Misalignment Final SD'][1], ashley[2]['Vertical Misalignment Final SD'][1], brendan[2]['Vertical Misalignment Final SD'][1], serena[2]['Vertical Misalignment Final SD'][1], mallika[2]['Vertical Misalignment Final SD'][1]]

#Defines the participant names, and arrays (?) for the final stats
names = ["AY", "AW", "BC", "ST", "MS"]
tests = ["Baseline", "Optivisor", "Overall Stats"]

plt.figure(figsize=(10,5))

plt.scatter(names, bVAN, c = 'Green', label = 'Baseline VAN')
plt.errorbar(names, bVAN, yerr=bVANSD, ls = 'none', c = 'Green')

plt.scatter(names, oVAN, c = 'Blue', label = 'Optivisor VAN')
plt.errorbar(names, oVAN, yerr=bVANSD, ls = 'none', c = 'Blue')

plt.title('VAN Grand Means')
plt.ylabel('Vertical Misalignment (°)')
plt.xlabel('Subjects')
plt.legend()
plt.show()

#plt.scatter(x = ['Arjun','Arjun','Arjun','Arjun','Arjun','Arjun','Arjun','Arjun','Arjun','Arjun'], y = arjun[0]['Vertical Misalignment Means'])

# data = {names[0]: VAN[0], names[1]: VAN[1], names[2]: VAN[2], names[2]: VAN[4]}
# nameList = list(data.keys())
# values = list(data.values())
# fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
# axs[0].bar(nameList, values)
# axs[1].scatter(nameList, values)
# axs[2].plot(nameList, values)

# dfVAN = pd.DataFrame({"id": names, 
#                    "mean": VAN, 
#                    "sd": VANSD})
# plt.errorbar(np.arange(len(dfVAN['id'])), dfVAN['mean'], yerr=dfVAN['sd'], ls='None', marker='o')
# ax = plt.gca()
# ax.xaxis.set_ticks(np.arange(len(df['id'])))
# ax.xaxis.set_ticklabels(df['id'], rotation=90)
# plt.xlabel("id")
# plt.ylabel("mean")

# plt.show()

# %%
bTAN = [arjun[2]['AngEnd Final Means'][0], ashley[2]['AngEnd Final Means'][0], brendan[2]['AngEnd Final Means'][0], serena[2]['AngEnd Final Means'][0], mallika[2]['AngEnd Final Means'][0]]
bTANSD = [arjun[2]['AngEnd Final SD'][0], ashley[2]['AngEnd Final SD'][0], brendan[2]['AngEnd Final SD'][0], serena[2]['AngEnd Final SD'][0], mallika[2]['AngEnd Final SD'][0]]
oTAN = [arjun[2]['AngEnd Final Means'][1], ashley[2]['AngEnd Final Means'][1], brendan[2]['AngEnd Final Means'][1], serena[2]['AngEnd Final Means'][1], mallika[2]['AngEnd Final Means'][1]]
oTANSD = [arjun[2]['AngEnd Final SD'][1], ashley[2]['AngEnd Final SD'][1], brendan[2]['AngEnd Final SD'][1], serena[2]['AngEnd Final SD'][1], mallika[2]['AngEnd Final SD'][1]]

#Defines the participant names, and arrays (?) for the final stats
names = ["AY", "AW", "BC", "ST", "MS"]
tests = ["Baseline", "Optivisor", "Overall Stats"]

plt.figure(figsize=(10,5))

plt.scatter(names, bVAN, c = 'Green', label = 'Baseline TAN')
plt.errorbar(names, bVAN, yerr=bVANSD, ls = 'none', c = 'Green')

plt.scatter(names, oVAN, c = 'Blue', label = 'Optivisor TAN')
plt.errorbar(names, oVAN, yerr=bVANSD, ls = 'none', c = 'Blue')

plt.title('TAN Grand Means')
plt.ylabel('Tortional Misalignment (°)')
plt.xlabel('Subjects')
plt.legend()
plt.show()
