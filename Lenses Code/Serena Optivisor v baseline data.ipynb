# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from pathlib import Path
from collections import namedtuple
from scipy import stats
import math

#Prevents pandas from truncating data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %matplotlib inline

# %%
#hard coding file pathways for first 2 tests (both VAN and TAN) for baseline and optivisor to variables
base1VAN = pd.read_csv('Serena-Data/Serena baseline 1_baseline_2021-03-15_14-31-39_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base1TAN = pd.read_csv('Serena-Data/Serena baseline 1_baseline_2021-03-15_14-32-01_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base2VAN = pd.read_csv('Serena-Data/Serena baseline 2_baseline_2021-03-15_14-35-13_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base2TAN = pd.read_csv('Serena-Data/Serena baseline 2_baseline_2021-03-15_14-35-31_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base3VAN = pd.read_csv('Serena-Data/Serena baseline 3_baseline_2021-03-15_14-36-07_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base3TAN = pd.read_csv('Serena-Data/Serena baseline 3_baseline_2021-03-15_14-36-22_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base4VAN = pd.read_csv('Serena-Data/Serena baseline 4_baseline_2021-03-15_14-37-00_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base4TAN = pd.read_csv('Serena-Data/Serena baseline 4_baseline_2021-03-15_14-37-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base5VAN = pd.read_csv('Serena-Data/Serena baseline 5_baseline_2021-03-15_14-37-49_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base5TAN = pd.read_csv('Serena-Data/Serena baseline 5_baseline_2021-03-15_14-38-09_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base6VAN = pd.read_csv('Serena-Data/Serena baseline 6_baseline_2021-03-16_14-34-19_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base6TAN = pd.read_csv('Serena-Data/Serena baseline 6_baseline_2021-03-16_14-34-39_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base7VAN = pd.read_csv('Serena-Data/Serena baseline 7_baseline_2021-03-16_14-35-16_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base7TAN = pd.read_csv('Serena-Data/Serena baseline 7_baseline_2021-03-16_14-35-36_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base8VAN = pd.read_csv('Serena-Data/Serena baseline 8_baseline_2021-03-16_14-36-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base8TAN = pd.read_csv('Serena-Data/Serena baseline 8_baseline_2021-03-16_14-36-27_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base9VAN = pd.read_csv('Serena-Data/Serena baseline 9_baseline_2021-03-16_14-37-03_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base9TAN = pd.read_csv('Serena-Data/Serena baseline 9_baseline_2021-03-16_14-37-20_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base10VAN = pd.read_csv('Serena-Data/Serena baseline 10_baseline_2021-03-16_14-37-50_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
base10TAN = pd.read_csv('Serena-Data/Serena baseline 10_baseline_2021-03-16_14-38-07_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)


opti1VAN = pd.read_csv('Serena-Data/Serena optovisor 1_baseline_2021-03-15_14-40-49_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti1TAN = pd.read_csv('Serena-Data/Serena optovisor 1_baseline_2021-03-15_14-41-15_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti2VAN = pd.read_csv('Serena-Data/Serena optovisor 2_baseline_2021-03-15_14-41-58_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti2TAN = pd.read_csv('Serena-Data/Serena optovisor 2_baseline_2021-03-15_14-42-20_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti3VAN = pd.read_csv('Serena-Data/Serena optovisor 3_baseline_2021-03-15_14-42-56_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti3TAN = pd.read_csv('Serena-Data/Serena optovisor 3_baseline_2021-03-15_14-43-18_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti4VAN = pd.read_csv('Serena-Data/Serena optovisor 4_baseline_2021-03-15_14-44-00_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti4TAN = pd.read_csv('Serena-Data/Serena optovisor 4_baseline_2021-03-15_14-44-20_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti5VAN = pd.read_csv('Serena-Data/Serena optovisor 5_baseline_2021-03-15_14-44-54_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti5TAN = pd.read_csv('Serena-Data/Serena optovisor 5_baseline_2021-03-15_14-45-14_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti6VAN = pd.read_csv('Serena-Data/Serena optovisor 6_baseline_2021-03-16_14-40-26_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti6TAN = pd.read_csv('Serena-Data/Serena optovisor 6_baseline_2021-03-16_14-40-46_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti7VAN = pd.read_csv('Serena-Data/Serena optovisor 7_baseline_2021-03-16_14-41-29_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti7TAN = pd.read_csv('Serena-Data/Serena optovisor 7_baseline_2021-03-16_14-41-44_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti8VAN = pd.read_csv('Serena-Data/Serena optovisor 8_baseline_2021-03-16_14-42-19_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti8TAN = pd.read_csv('Serena-Data/Serena optovisor 8_baseline_2021-03-16_14-42-34_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti9VAN = pd.read_csv('Serena-Data/Serena optovisor 9_baseline_2021-03-16_14-43-10_VAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti9TAN = pd.read_csv('Serena-Data/Serena optovisor 9_baseline_2021-03-16_14-43-25_TAN-Supine_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti10VAN = pd.read_csv('Serena-Data/Serena optovisor 10_baseline_2021-03-16_14-44-02_VAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)
opti10TAN = pd.read_csv('Serena-Data/Serena optovisor 10_baseline_2021-03-16_14-44-28_TAN-Sitting_VER2.txt', skiprows=3, delim_whitespace=True,skipinitialspace=True)

# %%
#Defines the participant names, and arrays (?) for the final stats (RMS = root mean square)
names = ["Serena"]
tests = ["Baseline", "Optivisor", "Overall Stats"]

##### serena edit: put angle offset calculation here so that you can just play with angle offset values instead of pixels
    # basically, you should take the raw data and convert that to angle offsets, and then calculate from there
    
#Finding ocular misalignment
baseHold = [base1VAN, base2VAN, base3VAN, base4VAN, base5VAN, base6VAN, base7VAN, base8VAN, base9VAN, base10VAN] #holds base data
optiHold = [opti1VAN, opti2VAN, opti3VAN, opti4VAN, opti5VAN, opti6VAN, opti7VAN, opti8VAN, opti9VAN, opti10VAN] # holds opti data
vertMis1 = [] #originally supposed to hold means for baseline, but it didn't work out how I expected (explained later)
vertMis2 = [] #originally supposed to hold means for optivisor, but it didn't work out how I expected (explained later)

for i in range(10):
    holderB = 0
    holderO = 0
    frame1 = baseHold[i] # holds baseline trial from baseHold array
    frame2 = optiHold[i] # holds optivisor trial from optiHold array
    for column in frame1[['YEnd']]:
        ang1 = 180/math.pi * np.arctan((frame1[column]/10)/207)
        ang2 = 180/math.pi * np.arctan((frame2[column]/10)/207)
        holderB += ang1
        holderO += ang2
    holderB /= 10
    holderO /= 10
    vertMis1.append(holderB) # idk why, but after this nested loop, both vertMis1 and vertMis2 hold every individual 
                            #test/10 instead of averages
    vertMis2.append(holderO)

vertMisBaseMean = [] #holds baseline misalignment means for each trial
vertMisOptiMean = [] #holds optivisor misalignment means for each trial
vertMisBaseSD = [] #holds baseline misalignment standard deviation for each trial
vertMisOptiSD = [] #holds optivisor misalignment standard deviation for each trial

for l in range (10):
    vertMisBaseMean.append(vertMis1[l].sum()) #summing each dataframe with misalignment in the verMis1 and 2 arrays
    vertMisOptiMean.append(vertMis2[l].sum())
    vertMisBaseSD.append(vertMis1[l].std())
    vertMisOptiSD.append(vertMis2[l].std())
# for i in range(10):
#     ang1 = 180/math.pi * np.arctan((baseStats['YEnd Means'][i]*10)/207)
#     ang2 = 180/math.pi * np.arctan((optiStats['YEnd Means'][i]*10)/207)
#     vertMis1.append(ang1)
#     vertMis2.append(ang2)
    
# print(vertMis1)


#creating a dictionary of all the values I need for the table so I don't have to print stuff individually

baseStats = {'Vertical Misalignment Means': vertMisBaseMean,
             'Vertical Misalignment SD': vertMisBaseSD,
             'Vertical Misalignment Final Mean': 0,
             'Vertical Misalignment Final SD': 0,
             'AngEnd Means': [base1TAN['AngEnd'].mean(), 
                              base2TAN['AngEnd'].mean(), 
                              base3TAN['AngEnd'].mean(), 
                              base4TAN['AngEnd'].mean(), 
                              base5TAN['AngEnd'].mean(), 
                              base6TAN['AngEnd'].mean(), 
                              base7TAN['AngEnd'].mean(), 
                              base8TAN['AngEnd'].mean(), 
                              base9TAN['AngEnd'].mean(), 
                              base10TAN['AngEnd'].mean()], 
             'AngEnd SD': [base1TAN['AngEnd'].std(), 
                           base2TAN['AngEnd'].std(), 
                           base3TAN['AngEnd'].std(), 
                           base4TAN['AngEnd'].std(), 
                           base5TAN['AngEnd'].std(), 
                           base6TAN['AngEnd'].std(), 
                           base7TAN['AngEnd'].std(), 
                           base8TAN['AngEnd'].std(), 
                           base9TAN['AngEnd'].std(), 
                           base10TAN['AngEnd'].std()],
             'AngEnd Final Mean': 0, 
             'AngEnd Final SD': 0}

optiStats = {'Vertical Misalignment Means': vertMisOptiMean, 
             'Vertical Misalignment SD': vertMisOptiSD,
             'Vertical Misalignment Final Mean': 0,
             'Vertical Misalignment Final SD': 0, 
             'AngEnd Means': [opti1TAN['AngEnd'].mean(), 
                              opti2TAN['AngEnd'].mean(), 
                              opti3TAN['AngEnd'].mean(), 
                              opti4TAN['AngEnd'].mean(), 
                              opti5TAN['AngEnd'].mean(), 
                              opti6TAN['AngEnd'].mean(), 
                              opti7TAN['AngEnd'].mean(), 
                              opti8TAN['AngEnd'].mean(), 
                              opti9TAN['AngEnd'].mean(), 
                              opti10TAN['AngEnd'].mean()],
             'AngEnd SD': [opti1TAN['AngEnd'].std(), 
                           opti2TAN['AngEnd'].std(), 
                           opti3TAN['AngEnd'].std(), 
                           opti4TAN['AngEnd'].std(), 
                           opti5TAN['AngEnd'].std(), 
                           opti6TAN['AngEnd'].std(), 
                           opti7TAN['AngEnd'].std(), 
                           opti8TAN['AngEnd'].std(), 
                           opti9TAN['AngEnd'].std(), 
                           opti10TAN['AngEnd'].std()],
             'AngEnd Final Mean': 0, 
             'AngEnd Final SD': 0}


#Finding mean values for YEnd and AngEnd for both baseline and optivisor
baseStats['Vertical Misalignment Final Mean'] = np.mean(baseStats['Vertical Misalignment Means'])
baseStats['AngEnd Final Mean'] = np.mean(baseStats['AngEnd Means'])

optiStats['Vertical Misalignment Final Mean'] = np.mean(optiStats['Vertical Misalignment Means'])
optiStats['AngEnd Final Mean'] = np.mean(optiStats['AngEnd Means'])

#Finding the final standard deviation based on the means of each trial
baseStats['Vertical Misalignment Final SD'] = np.std(baseStats['Vertical Misalignment Means'])
baseStats['AngEnd Final SD'] = np.std(baseStats['AngEnd Means'])

optiStats['Vertical Misalignment Final SD'] = np.std(optiStats['Vertical Misalignment Means'])
optiStats['AngEnd Final SD'] = np.std(optiStats['AngEnd Means'])

#Creating dictionary of final stats
finalStats = {'Vertical Misalignment Final Means': [baseStats['Vertical Misalignment Final Mean'], 
                                                    optiStats['Vertical Misalignment Final Mean']],
              'Vertical Misalignment Final SD': [baseStats['Vertical Misalignment Final SD'], 
                                optiStats['Vertical Misalignment Final SD']],
              'Vertical Misalignment P-value': 0,
              'AngEnd Final Means': [baseStats['AngEnd Final Mean'], 
                                     optiStats['AngEnd Final Mean']],
              'AngEnd Final SD': [baseStats['AngEnd Final SD'], 
                                  optiStats['AngEnd Final SD']],
              'AngEnd P-value': 0
             }

#defining the dataframes to later print as tables
data1 = pd.DataFrame(data = baseStats)
data2 = pd.DataFrame(data = optiStats)
data3 = pd.DataFrame(data = finalStats)

data1.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
data2.index = ["Trial 1", "Trial 2", "Trial 3", "Trial 4", "Trial 5", "Trial 6", "Trial 7", "Trial 8", "Trial 9", "Trial 10"]
data3.index = ["Baseline", "Optivisor"]

# %% [markdown]
# ## Variable Descriptions
# YEnd Means: Mean YEnd value for each trial (using VAN tests)
# <br>AngEnd Means: Mean AngEnd value for each trial (using TAN tests)
# <br>YEnd SD: Standard deviation of YEnd for each trial (using VAN tests)
# <br>AngEnd SD: Standard deviation of AngEnd for each trial (using TAN tests)
# <br>YEnd RMS: Gives the root mean squared of YEnd for all trials (using VAN tests)
# <br>AngEnd RMS: Gives the root mean squared of AngEnd for all trials (using TAN tests)
# <br>YEnd Final SD: Gives the standard deviation of the YEnd means for all trials (using VAN tests)
# <br>AngEnd Final SD: Give the standard deviation of the AngEnd means for all trials (using TAN tests)

# %%
print(names[0])
print(tests[0])
data1

# serena comments:
    # table looks really great! 
    # based on all the papers it seems like they just go with regular mean and SD, so you can get rid of the RMS and stuff (done)
    # what is 0 and 1, try to specify the row nams
    # everything else looks good, add a couple more lines to include the rest of your data so we can look at everything together
    
#Keep YEnd means, yend sd, yend final mean, yend final sd, angend means, angends sd, angend final mean, angend final sd (done)
#extra table: baseline is first row and optivisor is second row; for each column: final means and sd
# Out:
# Serena
# Baseline
#           Vertical Misalignment Means  Vertical Misalignment SD  \
# Trial 1                     -0.005259                  0.011225
# Trial 2                     -0.058126                  0.010874
# Trial 3                     -0.253814                  0.015983
# Trial 4                     -0.086359                  0.008466
# Trial 5                      0.063928                  0.034419
# Trial 6                     -0.194304                  0.021156
# Trial 7                     -0.251876                  0.016198
# Trial 8                     -0.148083                  0.008769
# Trial 9                     -0.124555                  0.013077
# Trial 10                    -0.123724                  0.016767
#
#           Vertical Misalignment Final Mean  Vertical Misalignment Final SD  \
# Trial 1                          -0.118217                        0.096729
# Trial 2                          -0.118217                        0.096729
# ...

# %%
print(names[0])
print(tests[1])
data2
# Out:
# Serena
# Optivisor
#           Vertical Misalignment Means  Vertical Misalignment SD  \
# Trial 1                     -0.302522                  0.049188
# Trial 2                      0.037366                  0.016155
# Trial 3                     -0.206208                  0.011824
# Trial 4                     -0.252153                  0.017066
# Trial 5                     -0.042626                  0.006125
# Trial 6                     -0.457248                  0.010337
# Trial 7                      0.052867                  0.018741
# Trial 8                     -0.323288                  0.010683
# Trial 9                     -0.263778                  0.015226
# Trial 10                    -0.426525                  0.015446
#
#           Vertical Misalignment Final Mean  Vertical Misalignment Final SD  \
# Trial 1                          -0.218411                        0.170789
# Trial 2                          -0.218411                        0.170789
# ...

# %% [markdown]
# ## next step:
# - put the final angle offset values into the table (replace Yend final means)
# - sanity check: look at kara beaton's paper and see if your data looks anything like hers
#     - if not, check the code/data
# - try to put people in a loop, otherwise ignore and just everyone's data for comparison
# - do the stats:
#     - (probably, but ask mallika) do a ttest on your own data (baseline vs. optivisor)
#     - (eventually when you have a loop or something to get everyone else's data) perform anova (i think)

# %%
# you can convert everything to visual angle offset (within each trial and then found mean) within the table or in a separate table, maybe separate table will
# look better in the end but up to you
# formula from paper: 
    # vertical ocular misalignment = 180/pi * arctan(((pm - ps)*d)/pp)
        # where pm-ps is yend, d is the distance between the head and the screen, and pp is the tablet's resolution in px/inch
    # torsional = am
        # where am is just angend

# %%
#Shapiro-Wilk test to check for normal distribution
stats.shapiro(data1['Vertical Misalignment Means']) #baseline
# first value is w (what is this?) and the second value is the p value
# null hypothesis is that the data is normally distributed
# since p>0.05, we can assume it's normally distributed
# Out:
# ShapiroResult(statistic=0.9633390307426453, pvalue=0.8231710195541382)

# %%
stats.shapiro(data2['Vertical Misalignment Means']) #optivisor
# first value is w (what is this?) and the second value is the p value
# null hypothesis is that the data is normally distributed
# since p>0.05, we can assume it's normally distributed
# Out:
# ShapiroResult(statistic=0.9189022779464722, pvalue=0.3478904366493225)

# %%
#t-test for VAN
vertMisT = stats.ttest_rel(data1['Vertical Misalignment Means'], data2['Vertical Misalignment Means'])
data3['Vertical Misalignment P-value'] = vertMisT[1]

# %%
#t-test for TAN
angMisT = stats.ttest_rel(data1['AngEnd Means'], data2['AngEnd Means'])
data3['AngEnd P-value'] = angMisT[1]

# %%
print(names[0])
print(tests[2])
data3
# Out:
# Serena
# Overall Stats
#            Vertical Misalignment Final Means  Vertical Misalignment Final SD  \
# Baseline                           -0.118217                        0.096729
# Optivisor                          -0.218411                        0.170789
#
#            Vertical Misalignment P-value  AngEnd Final Means  AngEnd Final SD  \
# Baseline                        0.138519               0.410         0.650538
# Optivisor                       0.138519               0.237         0.444276
#
#            AngEnd P-value
# Baseline         0.535372
# Optivisor        0.535372
